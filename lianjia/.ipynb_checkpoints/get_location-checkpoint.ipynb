# %%
import json
from urllib.request import urlopen,quote
from urllib import parse
import pandas as pd 
import traceback
import os
import re
import numpy as np
import time
import datetime
import requests as rq
def get_location(address='上海市',impulse=5):
    query = {
     'key' : 'fGrKDFGpFcF8jKDTqDrSzdNazWq5zicB',
     'output':'json',
      }
    query['address']=address
    base = 'http://api.map.baidu.com/geocoder?'
    url = base+parse.urlencode(query)
    #print(url)
    for _ in range(3):
        try:
            doc=urlopen(url).read().decode('utf-8')
            jsonData=json.loads(doc)
            location=jsonData['result']['location']
            return(location)
        except Exception as e:
            print(e)
    return

from math import radians, cos, sin, asin, sqrt  
      
def haversine(lon1, lat1, lon2, lat2): # 经度1，纬度1，经度2，纬度2 （十进制度数）  
        """ 
        Calculate the great circle distance between two points  
        on the earth (specified in decimal degrees) 
        """  
        # 将十进制度数转化为弧度  
        lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])  
      
        # haversine公式  
        dlon = lon2 - lon1   
        dlat = lat2 - lat1   
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2  
        c = 2 * asin(sqrt(a))   
        r = 6371 # 地球平均半径，单位为公里  
        return (c * r )

# %%
def gaode_location(keyword='',city='上海市',impulse=5):
    s=rq.session()
    #base_url='//restapi.amap.com/v3/place/text?key=2d0b7ddea6592e591fb3aa0ee0c8db30&keywords=%s&city=%s&children=1&offset=20&page=1&extensions=base'
    base_url='https://restapi.amap.com/v3/geocode/geo?address=%s&key=2d0b7ddea6592e591fb3aa0ee0c8db30'
    url=base_url%(city+keyword)
    #url=base_url%(keyword,city)
    for _ in range(3):
        try:
            web=s.get(url)
            address=web.json()['geocodes'][0]
            location=address['location'].split(',')+[address['formatted_address'],address['level']]
            return(location)
        except Exception as e:
            time.sleep(impulse)
            print(e)
    return

def search_location(keyword='',city='上海市',impulse=5):
    s=rq.session()
    base_url='https://restapi.amap.com/v3/place/text?keywords=%s&city=%s&offset=20&page=1&key=2d0b7ddea6592e591fb3aa0ee0c8db30&extensions=base'
    url=base_url%(keyword,city)
    for _ in range(3):
        try:
            web=s.get(url)
            address=web.json()['pois'][0]
            location=address['location'].split(',')+[address['name'],address['type']]
            return(location)
        except Exception as e:
            time.sleep(impulse)
            print(e)
    return
    
def correct_location(x):
    temp=search_location(x['fullname'])
    if temp :
        x['local']=temp
        x['lng']=temp[0]
        x['lat']=temp[1]
        x['level']=temp[3]
        x['formatname']=temp[2]
    return(x)
# location=data[['name','district','region']].drop_duplicates()
# location['fullname']=location['district']+'区'+location['name']
# location['fullname']=location['fullname'].map(lambda x: str(x).replace('浦东区','浦东新区'))
# location['local']=location['fullname'].map(lambda x: gaode_location(x))
# location['lng']=location['local'].map(lambda x: x[0])
# location['lat']=location['local'].map(lambda x: x[1])
# location['level']=location['local'].map(lambda x: x[3])
# location['formatname']=location['local'].map(lambda x: x[2])

#location_test=location.loc[(location['level']=='区县') | (location['level']=='热点商圈'),]
#location_test=location_test.apply(correct_location,axis=1)
#location.loc[(location['level']=='区县') | (location['level']=='热点商圈'),['local','lng','lat','level','formatname']]=location_test[['local','lng','lat','level','formatname']]

# %%
new=pd.read_csv('new.csv')
data=pd.read_csv('sold.csv')
data=data.append(new,ignore_index=True)
data=data.sort_values('dealdate')
data=data.drop_duplicates(subset='link',keep='first')
data.to_csv('sold.csv',index=False)

# %%
#data=pd.read_csv('sold.csv')
data=data.sort_values('district')
data.index=range(0,len(data))
data=data.drop_duplicates(subset='link',keep='first')

data['space']=data['space'].map(lambda x: float(x.split('平')[0]) if x.find('平')>=0 else np.nan)
data['Price']=data['dealInfo'].map(lambda x: float(re.findall('\d+\.?\d*',x)[0]) if len(re.findall('\d+\.?\d*',x))==2 else np.nan)
data['Selldays']=data['dealInfo'].map(lambda x: float(re.findall('\d+\.?\d*',x)[1]) if len(re.findall('\d+\.?\d*',x))==2 else re.findall('\d+',x)[0])
data['Totalprice']=data['totalprice'].map(lambda x: float((x.split('万')[0])) if ('*' not in x and  "万"in x) else np.nan)
data['Unitprice']=data['unitprice'].map(lambda x: float(re.findall('\d+\.?\d*',x)[0]) if len(re.findall('\d+\.?\d*',x))==1 else np.nan)
data['date']=data['dealdate'].map(lambda x: x.replace('.','-').replace('近30天内成交',str(datetime.date.today()-datetime.timedelta(30))))
data['date']=data['date'].astype('datetime64[ns]')
data['zhuangxiu']=data['zhuangxiu'].map(lambda x: x.replace(' ','').replace('\xa0',''))

testdata=data.loc[(~data['Unitprice'].isnull()) & (~data['Price'].isnull()),]
discount=testdata['Totalprice'].mean()/testdata['Price'].mean()

data.loc[(data['Unitprice'].isnull()),'Totalprice']=data.loc[(data['Unitprice'].isnull()),'Price']*discount
data.loc[(data['Unitprice'].isnull()),'Unitprice']=data.loc[(data['Unitprice'].isnull()),
                                                            'Totalprice']/data.loc[(data['Unitprice'].isnull()),'space']*10000

hx=data.groupby('huxing').count().sort_values('name',ascending=False).index[0:9]
data['huxing']=data['huxing'].apply(lambda x: x if x in hx else '其他')
data['age']=data['position'].apply(lambda x: re.findall('\d*[0-9]',x)).apply(lambda x: 2018-int(x[1]) if len(x)==2 else np.nan)
data['year']=data['date'].astype(str).apply(lambda x: int(x.split('-')[0]))
data['floors']=data['position'].apply(lambda x: re.findall('\d*[0-9]层',x)).apply(lambda x: int(x[0].replace('层','')) if len(x)==1 else np.nan)
data['floors']=data['floors'].apply(lambda x : x if x <=40 else np.nan )
data['lifts']=data['floors'].apply(lambda x: '有电梯' if x>=7 else '无电梯')
data['buildyear']=data['position'].apply(lambda x: re.findall('\d*[0-9]年',x)).apply(lambda x: x[0] if len(x)==1 else np.nan)
year=data.groupby('buildyear').count().sort_values('name',ascending=False).index[0:30]
data['buildyear']=data['buildyear'].apply(lambda x : x if x in year else '其他')
data['metro']=data['HouseInfo'].apply(lambda x: re.findall('\d*[0-9]号线',str(x))).apply(lambda x: x[0] if len(x)==1 else np.nan)
metro=data.sort_values('metro')[['name','district','region','metro']].drop_duplicates()
metro=metro.drop_duplicates(subset=['name','region'])
data=pd.merge(data,metro,on=['name','district','region'],how='left',suffixes=['','s'])
data['车位']=data['position'].apply(lambda x :1 if '车位' in x else 0)

#data=data.set_index('date')



#location.to_csv('location.csv',index=False)


# location=pd.read_csv('location.csv')

# locat=data[['name','district','region']].drop_duplicates()
# locat['fullname']=locat['district']+'区'+locat['name']
# locat['fullname']=locat['fullname'].map(lambda x: str(x).replace('浦东区','浦东新区'))
# locat=locat.loc[~locat['fullname'].isin(location['fullname']),].copy()
# locat['local']=locat['fullname'].map(lambda x: get_location("上海市"+x))
# locat['lat']=locat['local'].map(lambda x: x['lat'] if x else np.nan)
# locat['lng']=locat['local'].map(lambda x: x['lng'] if x else np.nan)
# location=location.append(locat,ignore_index=True)

# location.to_csv('location.csv',index=True)

location=pd.read_excel('gaode_location.xlsx')
locat=data[['name','district','region']].drop_duplicates()
locat['fullname']=locat['district']+'区'+locat['name']
locat['fullname']=locat['fullname'].map(lambda x: str(x).replace('浦东区','浦东新区'))
locat=locat.loc[~locat['fullname'].isin(location['fullname']),].copy()
locat['local']=locat['fullname'].map(lambda x: gaode_location(x))
locat['lng']=locat['local'].map(lambda x: x[0])
locat['lat']=locat['local'].map(lambda x: x[1])
locat['level']=locat['local'].map(lambda x: x[3])
locat['formatname']=locat['local'].map(lambda x: x[2])
location=location.append(locat,ignore_index=True)
location.to_excel('gaode_location.xlsx')


data=pd.merge(data,location[['name','district','lat','lng']],on=['name','district'],how='left')
data=data.loc[~data['Unitprice'].isnull(),]
data=data.loc[data['车位']==0,]
data=data.loc[(data['Totalprice']>data['Totalprice'].quantile(0.001)) & (data['Totalprice']<data['Totalprice'].quantile(0.999)), ]                                                 
# data[['name','district','region','huxing','space','chaoxiang',
#        'zhuangxiu', 'lifts', 'position','metros', 'dealInfo', 'Totalprice',
#        'Unitprice', 'date', 'age','floors','buildyear','lat', 'lng']].to_csv('formatsold.csv',index=False)
formatdata=data[['name','district','region','huxing','space','chaoxiang',
       'zhuangxiu', 'lifts', 'position','metros', 'dealInfo', 'Totalprice',
       'Unitprice', 'date', 'age','floors','buildyear','lat', 'lng']].copy()
formatdata.columns=['小区','区域','街道','户型','面积','朝向','装修','电梯',
                    '楼层','地铁','交易信息','总价','单价','成交日期','楼龄','楼高','建筑年代','纬度','经度']
formatdata.to_csv('formatsold.csv',index=False)

# %%
data.head()
# Out:
#         name district region huxing  space chaoxiang zhuangxiu  lift  \
# 0       新城金郡       嘉定   嘉定新城   2室2厅  82.66        南         精装   有电梯
# 1  嘉宝紫提湾(公寓)       嘉定   嘉定新城   2室2厅  91.70        南         精装   有电梯
# 2    塔城路800弄       嘉定   嘉定老城   2室1厅  81.00        南         简装   无电梯
# 3       金华新村       嘉定     江桥   2室1厅  71.40        南         精装   无电梯
# 4   万达广场(嘉定)       嘉定     江桥   1室0厅  44.05     暂无数据         其他   NaN
#
#              position        dealInfo   ...      age  year floors lifts  \
# 0  中楼层(共18层) 2011年建板楼   挂牌325万成交周期64天   ...      7.0  2018   18.0   有电梯
# 1  中楼层(共25层) 2012年建板楼  挂牌355万成交周期383天   ...      6.0  2018   25.0   有电梯
# 2   高楼层(共4层) 1998年建板楼  挂牌225万成交周期120天   ...     20.0  2018    4.0   无电梯
# 3   高楼层(共6层) 1994年建板楼  挂牌263万成交周期272天   ...     24.0  2018    6.0   无电梯
# 4  中楼层(共11层) 2011年建塔楼  挂牌110万成交周期466天   ...      7.0  2016   11.0   有电梯
#
#   buildyear  metro metros  车位      lat      lng
# 0     2011年   11号线   11号线   0  31.3434  121.241
# 1     2012年    NaN    NaN   0  31.3338  121.279
# 2     1998年   11号线   11号线   0  31.3731  121.236
# 3     1994年    NaN    NaN   0  31.2319  121.327
# 4     2011年    NaN   13号线   0  31.2387  121.323
#
# [5 rows x 30 columns]

# %%
data['year']=data['date'].apply(lambda x: str(x).split('-')[0])
data=data.loc[(data['Totalprice']>data['Totalprice'].quantile(0.005)) & (data['Totalprice']<data['Totalprice'].quantile(0.995)), ]
testdata=data[['name','district','region','space',
        'lifts', 'Totalprice', 'Unitprice', 'year', 'age','floors','metros']].copy()
testdata['Unitprice']=testdata['Unitprice']/10000
testdata['metro']=testdata['metros'].apply(lambda x: 1 if isinstance(x,str) else 0)
testdata['lift']=testdata['lifts'].apply(lambda x: 0 if x=="无电梯" else 1)
xiaoqu=testdata.groupby(['name','district']).count()[['region']].join(pd.pivot_table(testdata,index='name',values=['space','age','metro','lift'],
                     aggfunc=np.mean))
yearly=pd.pivot_table(testdata.loc[~testdata['year'].isin(['2015','2019']),],index='name',columns='year',
                     values=['Totalprice','Unitprice'],aggfunc=np.mean)
yearly.columns=['Totalprice2016','Totalprice2017','Totalprice2018','Unitprice2016','Unitprice2017','Unitprice2018']
xiaoqu=xiaoqu.join(yearly)
xiaoqu=xiaoqu.rename(columns={'region':'Count'})
xiaoqu=xiaoqu.query('Count>2')
xiaoqu=xiaoqu.loc[~((xiaoqu['Totalprice2016'].isnull()) & (xiaoqu['Totalprice2017'].isnull())),]
xiaoqu=xiaoqu.loc[~((xiaoqu['Totalprice2016'].isnull()) & (xiaoqu['Totalprice2018'].isnull())),]
xiaoqu=xiaoqu.loc[~((xiaoqu['Totalprice2017'].isnull()) & (xiaoqu['Totalprice2018'].isnull())),]
xiaoqu=xiaoqu.reset_index()
xiaoqu.columns=['小区名称','区域','已售','楼龄','电梯','地铁','面积','总价1','总价2','总价3','单价1','单价2','单价3']
xiaoqu.to_csv('xiaoqu.csv',index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn import datasets
import graphviz 
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(trans, xiaoqu_target)
np.random.seed(5)

trans =xiaoqu.fillna(0)
X = scale(trans )

estimator=KMeans(n_clusters=6)
fit=estimator.fit(X)
xiaoqu_target=fit.labels_

dot_data = tree.export_graphviz(clf, out_file=None,  
                         filled=True, rounded=True,  
                         special_characters=True) 
graph = graphviz.Source(dot_data)

# %%
formatdata
# Out:
#                   小区  区域    街道    户型      面积     朝向  装修   电梯  \
# 0           尚都国际酒店公寓  嘉定    安亭  1室1厅   54.60    西南   精装  有电梯
# 1              嘉城新航域  嘉定    江桥  2室2厅   83.12     南   其他  无电梯
# 2               汇丰佳苑  嘉定    丰庄  3室2厅  130.40     南   其他  有电梯
# 3               水仙小区  嘉定    安亭  1室1厅   43.11     南   其他  无电梯
# 4               永翔佳苑  嘉定    南翔  2室1厅   56.42     南   其他  有电梯
# 5               金沙鼎苑  嘉定    江桥  1室1厅   56.15     南   其他  有电梯
# 6           红梅小区(嘉定)  嘉定    安亭  2室1厅   69.91     南   其他  无电梯
# 7               芙蓉新村  嘉定    安亭  2室1厅   94.75     南   其他  无电梯
# 8               吴杨雅苑  嘉定    江桥  2室2厅   88.00   南 北   简装  无电梯
# 9               华江一村  嘉定    江桥  1室1厅   45.30     南   其他  无电梯
# 10         左岸香堤(商业类)  嘉定  嘉定新城  2室2厅   33.26     西   精装  无电梯
# 11              玉兰四村  嘉定    安亭  3室2厅  123.21  暂无数据   其他  无电梯
# 12              澜茵华庭  嘉定    江桥  2室2厅   73.20     南   其他  无电梯
# 13           中信泰富又一城  嘉定  嘉定新城  2室2厅   89.86   南 北   毛坯  有电梯
# 14              水岸秀苑  嘉定    江桥  3室2厅   99.90     南   精装  有电梯
# 15              合景峰汇  嘉定  嘉定新城  2室2厅   42.51     南   其他  有电梯
# 16          爱德佳苑(三期)  嘉定    江桥  1室2厅   61.26     南   其他  有电梯
# 17        旭辉U天地(商业类)  嘉定    南翔  2室1厅   48.72  暂无数据   其他  有电梯
# 18              东方慧谷  嘉定    马陆  2室1厅   45.00    西南   其他  有电梯
# 19            骏丰嘉骊花园  嘉定    南翔  2室2厅   76.00    西南   其他  有电梯
# 20             绿地清猗园  嘉定    南翔  2室2厅   91.00     南   精装  有电梯
# 21              右岸嘉园  嘉定  嘉定老城  2室2厅   85.00     南   其他  有电梯
# 22              汇丰沁苑  嘉定    江桥  3室2厅  128.00   南 北   其他  无电梯
# 23              恒嘉花园  嘉定    江桥  2室2厅   87.51     南   其他  有电梯
# 24         龙湖蓝湖郡(别墅)  嘉定  嘉定新城  4室2厅  326.89     南   简装  无电梯
# 25             嘉城雅颂湾  嘉定    江桥  2室2厅   88.28     南   其他  无电梯
# 26            丰庄十二街坊  嘉定    丰庄  2室1厅   61.00     南   其他  无电梯
# 27          桃园新村(嘉定)  嘉定  嘉定老城  1室1厅   43.43  暂无数据   其他  无电梯
# 28              江桥二村  嘉定    江桥  1室1厅   42.54     南   其他  无电梯
# 29              永翔佳苑  嘉定    南翔  2室2厅   87.68     南   其他  有电梯
# ...              ...  ..   ...   ...     ...    ...  ..  ...
# 82455           祥茂新村  黄浦   新天地  1室0厅    9.70     北   其他  无电梯
# 82456          淡水湾花园  黄浦   新天地  1室1厅   54.94  暂无数据   简装  有电梯
# 82457           公馆77  黄浦   老西门  4室2厅  169.00     南   精装  有电梯
# 82458           海洲丽园  黄浦  蓬莱公园  1室0厅   32.96  暂无数据   其他  无电梯
# 82459           双钱公寓  黄浦   打浦桥  2室2厅  116.55    西南   其他  有电梯
# 82460           海潮新村  黄浦  蓬莱公园  1室0厅   35.54     南   其他  无电梯
# 82461           西凌新邨  黄浦  蓬莱公园  2室1厅   86.83     西   其他  有电梯
# 82462           西凌新邨  黄浦  蓬莱公园  1室0厅   35.36     南   其他  无电梯
# 82463           海洲丽园  黄浦  蓬莱公园  2室2厅  114.00  暂无数据   其他  有电梯
# 82464           南园新村  黄浦   打浦桥  2室1厅   54.12     南   其他  无电梯
# 82465           中南小区  黄浦  世博滨江  2室1厅   60.69  暂无数据   其他  有电梯
# 82466           华府天地  黄浦   新天地    其他  301.23     南   其他  有电梯
# 82467       陆家浜路413弄  黄浦   董家渡  1室1厅   41.42  暂无数据   其他  无电梯
# 82468         卢湾都市花园  黄浦   五里桥  2室2厅   96.46     南   其他  有电梯
# 82469       国际广场(卢湾)  黄浦   新天地  4室2厅  225.32    东北   其他  有电梯
# 82470           市民新村  黄浦  世博滨江  2室0厅   42.64     南   其他  无电梯
# 82471          上海滩花园  黄浦  黄浦滨江  2室2厅  131.26     南   精装  有电梯
# 82472           中复小区  黄浦    豫园  1室0厅   33.74     南   其他  无电梯
# 82473           天天花园  黄浦   打浦桥  2室2厅  133.41    东北   精装  有电梯
# 82474        融创滨江壹号院  黄浦  世博滨江  2室2厅  114.59     南   其他  有电梯
# 82475            新地苑  黄浦    豫园  3室2厅  146.21    东南   其他  有电梯
# 82476           桥一小区  黄浦   五里桥  1室1厅   30.14     南   其他  有电梯
# 82477           海华花园  黄浦   打浦桥  3室2厅  117.37    西南   其他  有电梯
# 82478    牯岭路166-176号  黄浦  人民广场  1室0厅   22.40     南   简装  无电梯
# 82479      中山南一路161弄  黄浦  世博滨江  2室0厅   46.29     南   其他  无电梯
# 82480  华丽家族汇景天地(商业类)  黄浦   五里桥    其他  114.17    西北   其他  无电梯
# 82481           汇龙新城  黄浦   五里桥  3室2厅  158.30     南   其他  有电梯
# 82482           百溪公寓  黄浦   五里桥  1室1厅   36.01  暂无数据   其他  有电梯
# 82483           蒙自新村  黄浦   五里桥  1室0厅   33.42     南   其他  有电梯
# 82484          济南路8号  黄浦   新天地  1室2厅   82.74     西   其他  有电梯
#
#                          楼层    地铁              交易信息      总价        单价  \
# 0        中楼层(共15层) 2012年建塔楼   NaN     挂牌70万成交周期179天    53.0    9707.0
# 1         中楼层(共6层) 2009年建板楼   NaN    挂牌350万成交周期499天   345.0   41507.0
# 2        中楼层(共11层) 2004年建板楼  13号线    挂牌540万成交周期484天   530.0   40645.0
# 3         低楼层(共5层) 1983年建板楼   NaN          成交周期444天   104.5   24241.0
# 4        低楼层(共17层) 2011年建板楼   NaN          成交周期489天   225.0   39880.0
# 5        低楼层(共18层) 2012年建板楼   NaN    挂牌220万成交周期610天   160.0   28496.0
# 6         高楼层(共6层) 1983年建板楼  11号线    挂牌208万成交周期758天   205.0   29324.0
# 7         高楼层(共6层) 2002年建板楼  11号线          成交周期418天   252.0   26597.0
# 8         中楼层(共6层) 2009年建板楼   NaN     挂牌328万成交周期72天   321.0   36478.0
# 9         高楼层(共6层) 1995年建板楼   NaN          成交周期488天   188.0   41502.0
# 10        中楼层(共5层) 2011年建板楼   NaN     挂牌85万成交周期227天    80.0   24053.0
# 11        高楼层(共6层) 1999年建板楼   NaN    挂牌380万成交周期445天   206.0   16720.0
# 12        中楼层(共6层) 2005年建板楼  13号线    挂牌350万成交周期594天   335.0   45766.0
# 13       中楼层(共36层) 2011年建板楼  11号线     挂牌345万成交周期45天   335.0   37281.0
# 14       中楼层(共11层) 2006年建板楼  13号线    挂牌410万成交周期270天   398.0   39840.0
# 15       低楼层(共19层) 2015年建塔楼   NaN    挂牌125万成交周期540天   118.0   27759.0
# 16       低楼层(共14层) 2013年建板楼   NaN    挂牌240万成交周期304天   240.0   39178.0
# 17     中楼层(共12层) 2014年建暂无数据  11号线    挂牌180万成交周期415天   109.0   22373.0
# 18       中楼层(共22层) 2013年建塔楼   NaN     挂牌75万成交周期136天    75.0   16667.0
# 19       高楼层(共10层) 2012年建板楼  11号线    挂牌160万成交周期325天   156.0   20527.0
# 20       高楼层(共13层) 2013年建板楼  11号线     挂牌460万成交周期98天   445.0   48902.0
# 21       中楼层(共11层) 2009年建板楼   NaN    挂牌320万成交周期570天   308.0   36236.0
# 22        低楼层(共6层) 2006年建板楼   NaN     挂牌530万成交周期59天   505.0   39454.0
# 23        中楼层(共7层) 2001年建板楼   NaN    挂牌325万成交周期574天   318.0   36339.0
# 24        低楼层(共3层) 2010年建板楼  11号线    挂牌860万成交周期263天   835.0   25544.0
# 25        高楼层(共6层) 2008年建板楼   NaN    挂牌365万成交周期497天   365.0   41346.0
# 26        中楼层(共6层) 1997年建板楼  13号线    挂牌298万成交周期617天   296.0   48525.0
# 27        低楼层(共6层) 1987年建板楼  11号线    挂牌158万成交周期589天   149.0   34309.0
# 28        低楼层(共6层) 1997年建板楼   NaN    挂牌217万成交周期592天   208.5   49013.0
# 29       低楼层(共17层) 2011年建板楼   NaN    挂牌260万成交周期446天   251.0   28627.0
# ...                     ...   ...               ...     ...       ...
# 82455           低楼层(共3层) 板楼   NaN     挂牌90万成交周期255天    79.0   81444.0
# 82456    中楼层(共28层) 2007年建板楼   NaN    挂牌750万成交周期358天   713.0  129778.0
# 82457    中楼层(共26层) 2012年建板楼   8号线   挂牌1800万成交周期236天   900.0   53255.0
# 82458           地下室(共1层) 板楼   NaN      挂牌50万成交周期11天    47.0   14260.0
# 82459          低楼层(共30层) 塔楼   NaN   挂牌780万成交周期1098天   765.0   65638.0
# 82460     中楼层(共6层) 1993年建板楼   4号线   挂牌338万成交周期1170天   338.0   95105.0
# 82461    高楼层(共32层) 1995年建塔楼   4号线         成交周期1004天   545.0   62767.0
# 82462     中楼层(共6层) 1990年建板楼   4号线    挂牌263万成交周期184天   247.0   69853.0
# 82463    低楼层(共18层) 2005年建板楼   NaN   挂牌920万成交周期1974天   916.0   80351.0
# 82464     中楼层(共6层) 1988年建板楼   4号线    挂牌460万成交周期690天   447.0   82595.0
# 82465     中楼层(共7层) 1993年建板楼   4号线   挂牌610万成交周期1116天   600.0   98864.0
# 82466    低楼层(共20层) 2006年建板楼   NaN  挂牌3900万成交周期1955天  3400.0  112871.0
# 82467     中楼层(共6层) 1978年建板楼   4号线   挂牌355万成交周期1955天   343.0   82811.0
# 82468    高楼层(共28层) 2004年建板楼   NaN   挂牌750万成交周期1609天   735.0   76198.0
# 82469    高楼层(共28层) 1997年建塔楼   NaN  挂牌1300万成交周期1624天  1325.0   58806.0
# 82470     低楼层(共6层) 1965年建板楼   4号线         成交周期1092天   285.0   66839.0
# 82471    高楼层(共33层) 2008年建板楼   9号线    挂牌1500万成交周期39天  1495.0  113897.0
# 82472     中楼层(共6层) 1989年建板楼   NaN    挂牌310万成交周期133天   285.0   84470.0
# 82473    高楼层(共32层) 1997年建塔楼   9号线    挂牌800万成交周期278天   780.0   58467.0
# 82474    低楼层(共36层) 2012年建板楼  13号线   挂牌1150万成交周期899天  1020.0   89014.0
# 82475    高楼层(共29层) 1999年建板楼   NaN  挂牌1100万成交周期1650天  1050.0   71815.0
# 82476     高楼层(共7层) 1989年建板楼   4号线          成交周期917天   198.0   65694.0
# 82477    低楼层(共33层) 1994年建塔楼   NaN         成交周期1119天   747.0   63645.0
# 82478         高楼层(共4层) 暂无数据   NaN     挂牌280万成交周期69天   260.0  116072.0
# 82479     高楼层(共6层) 1982年建板楼   NaN          成交周期794天   200.0   43206.0
# 82480     中楼层(共5层) 2012年建板楼   4号线    挂牌550万成交周期561天   555.0   48612.0
# 82481    低楼层(共28层) 2002年建板楼   NaN  挂牌1500万成交周期1675天  1458.0   92104.0
# 82482     中楼层(共7层) 1993年建板楼   4号线          成交周期432天   260.0   72203.0
# 82483     高楼层(共7层) 1988年建板楼   4号线     挂牌1万成交周期1954天   280.0   83783.0
# 82484          中楼层(共31层) 塔楼   1号线   挂牌900万成交周期1535天   870.0  105149.0
#
#             成交日期    楼龄    楼高   建筑年代         经度          维度
# 0     2018-04-04   6.0  15.0  2012年  31.289898  121.180214
# 1     2016-09-04   9.0   6.0  2009年  31.271716  121.357059
# 2     2016-07-22  14.0  11.0  2004年  31.254189  121.369179
# 3     2016-07-22  35.0   5.0     其他  31.301422  121.165287
# 4     2016-09-04   7.0  17.0  2011年  31.364338  121.251014
# 5     2017-01-06   6.0  18.0  2012年  31.253975  121.314087
# 6     2017-06-04  35.0   6.0     其他  31.300769  121.165672
# 7     2016-09-04  16.0   6.0  2002年  31.299169  121.167003
# 8     2018-05-23   9.0   6.0  2009年  31.278927  121.309489
# 9     2016-09-04  23.0   6.0  1995年  31.270526  121.347468
# 10    2018-09-03   7.0   5.0  2011年  31.353538  121.264089
# 11    2016-07-22  19.0   6.0  1999年  31.302614  121.171665
# 12    2017-06-04  13.0   6.0  2005年  31.245166  121.322614
# 13    2018-05-23   7.0  36.0  2011年  31.332041  121.274595
# 14    2018-01-20  12.0  11.0  2006年  31.246006  121.315233
# 15    2017-01-07   3.0  19.0     其他  31.350191  121.265331
# 16    2016-09-04   5.0  14.0  2013年  31.238160  121.321167
# 17    2016-09-04   4.0  12.0  2014年  31.308134  121.331984
# 18    2016-09-04   5.0  22.0  2013年  31.338711  121.298266
# 19    2016-07-22   6.0  10.0  2012年  31.294563  121.324603
# 20    2018-01-20   5.0  13.0  2013年  31.303579  121.326498
# 21    2017-08-25   9.0  11.0  2009年  31.370332  121.253856
# 22    2018-05-23  12.0   6.0  2006年  31.262197  121.335220
# 23    2017-08-25  17.0   7.0  2001年  31.267900  121.359802
# 24    2018-01-20   8.0   3.0  2010年  31.332464  121.259986
# 25    2016-09-05  10.0   6.0  2008年  31.268804  121.351209
# 26    2017-08-25  21.0   6.0  1997年  31.253441  121.365958
# 27    2017-04-22  31.0   6.0  1987年  31.395364  121.252043
# 28    2017-06-04  21.0   6.0  1997年  31.261578  121.352812
# 29    2016-07-23   7.0  17.0  2011年  31.364338  121.251014
# ...          ...   ...   ...    ...        ...         ...
# 82455 2016-05-30   NaN   3.0     其他  31.227381  121.479491
# 82456 2018-01-05  11.0  28.0  2007年  31.216469  121.481880
# 82457 2018-01-05   6.0  26.0  2012年  31.219097  121.488400
# 82458 2016-05-29   NaN   1.0     其他  31.215994  121.495424
# 82459 2016-10-18   NaN  30.0     其他  31.212794  121.476115
# 82460 2017-05-16  25.0   6.0  1993年  31.215681  121.503308
# 82461 2016-08-28  23.0  32.0  1995年  31.211000  121.491822
# 82462 2018-10-30  28.0   6.0  1990年  31.211000  121.491822
# 82463 2018-01-03  13.0  18.0  2005年  31.215994  121.495424
# 82464 2017-02-14  30.0   6.0  1988年  31.203638  121.481265
# 82465 2017-05-15  25.0   7.0  1993年  31.205897  121.494808
# 82466 2017-05-15  12.0  20.0  2006年  31.225168  121.479900
# 82467 2017-05-15  40.0   6.0     其他  31.217839  121.505600
# 82468 2016-06-02  14.0  28.0  2004年  31.206930  121.483525
# 82469 2017-05-15  21.0  28.0  1997年  31.223776  121.489253
# 82470 2016-08-07  53.0   6.0     其他  31.209590  121.498749
# 82471 2017-09-12  10.0  33.0  2008年  31.224710  121.506572
# 82472 2018-08-06  29.0   6.0  1989年  31.227212  121.505176
# 82473 2017-12-31  21.0  32.0  1997年  31.213202  121.477574
# 82474 2016-06-02   6.0  36.0  2012年  31.203932  121.491798
# 82475 2017-05-15  19.0  29.0  1999年  31.227959  121.497786
# 82476 2016-06-01  29.0   7.0  1989年  31.227203  121.496072
# 82477 2016-06-01  24.0  33.0  1994年  31.210711  121.475574
# 82478 2017-12-31   NaN   4.0     其他  31.241878  121.477174
# 82479 2016-06-01  36.0   6.0     其他  31.206908  121.494186
# 82480 2018-05-23   6.0   5.0  2012年  31.205169  121.483917
# 82481 2016-08-07  16.0  28.0  2002年  31.213845  121.482674
# 82482 2016-05-31  25.0   7.0  1993年  31.206398  121.487901
# 82483 2017-05-15  30.0   7.0  1988年  31.207006  121.485840
# 82484 2017-05-19   NaN  31.0     其他  31.227656  121.484712
#
# [82055 rows x 19 columns]

# %%
a=pd.read_csv('location.csv')

# %%
b=pd.read_excel('gaode_location.xlsx')

# %%
location=pd.read_excel('gaode_location.xlsx')
locat=data[['name','district','region']].drop_duplicates()
locat['fullname']=locat['district']+'区'+locat['name']
locat['fullname']=locat['fullname'].map(lambda x: str(x).replace('浦东区','浦东新区'))
locat=locat.loc[~locat['fullname'].isin(location['fullname']),].copy()
locat['local']=locat['fullname'].map(lambda x: gaode_location(x))
locat['lng']=locat['local'].map(lambda x: x[0])
locat['lat']=locat['local'].map(lambda x: x[1])
locat['level']=locat['local'].map(lambda x: x[3])
locat['formatname']=locat['local'].map(lambda x: x[2])
location=location.append(locat,ignore_index=True)

# %%
locat=locat.apply(search_location,axis=1)
# Out:
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range

# %%
locat
# Out:
# 1892          [121.260316, 31.398805, 新城枫景, 商务住宅;住宅区;住宅小区]
# 5441          [121.495176, 30.953727, 金水领寓, 商务住宅;楼宇;商务写字楼]
# 5600       [121.619766, 30.914174, 上海玫瑰园商贸城, 购物服务;商场;普通商场]
# 5901     [121.416807, 31.154297, 康健新村(长丰坊)地面停车场, 交通设施服务...
# 5952          [121.743531, 30.896162, 平安家园, 商务住宅;住宅区;住宅小区]
# 7265     [121.617770, 30.900399, 塘外褚聚小区4号楼, 地名地址信息;门牌信息...
# 11779    [121.446327, 31.332785, 上海农商银行(长江西路支行), 金融保险服务...
# 16475     [121.370414, 31.784829, 洪联新村, 地名地址信息;普通地名;村庄级地名]
# 16478     [121.220897, 31.810890, 跃进新村, 地名地址信息;普通地名;村庄级地名]
# 16479          [121.412691, 31.76119, 长乐一村, 商务住宅;住宅区;住宅小区]
# 16482         [121.635058, 31.576855, 崇明岛, 地名地址信息;自然地名;岛屿]
# 16483          [121.416111, 31.76213, 长乐二村, 商务住宅;住宅区;住宅小区]
# 16485     [121.241703, 31.833199, 跃高新村, 地名地址信息;普通地名;村庄级地名]
# 16486                                                 None
# 16488         [121.635058, 31.576855, 崇明岛, 地名地址信息;自然地名;岛屿]
# 16489                                                 None
# 16490         [121.635058, 31.576855, 崇明岛, 地名地址信息;自然地名;岛屿]
# 16491     [121.370192, 31.792121, 洪中新村, 地名地址信息;普通地名;村庄级地名]
# 16492                                                 None
# 16494          [121.539514, 31.671351, 明华一村, 商务住宅;住宅区;住宅区]
# 16496         [121.635058, 31.576855, 崇明岛, 地名地址信息;自然地名;岛屿]
# 16501                                                 None
# 16502         [121.371115, 31.791776, 洪中二村, 商务住宅;住宅区;住宅小区]
# 16504         [121.536464, 31.675227, 长江二村, 商务住宅;住宅区;住宅小区]
# 16508      [121.302513, 31.818429, 新苑(兴垦路), 商务住宅;住宅区;住宅小区]
# 16516          [121.59924, 31.645778, 海鸥新村, 商务住宅;住宅区;住宅小区]
# 16736     [121.408815, 31.154141, 玫瑰园(桂江路), 商务住宅;住宅区;住宅小区]
# 18140    [121.454249, 31.164552, 云锦东方(建设中), 商务住宅;住宅区;住宅小区]
# 18261         [121.439659, 31.200476, 爱棠新邨, 商务住宅;住宅区;住宅小区]
# 18362    [121.454249, 31.164552, 云锦东方(建设中), 商务住宅;住宅区;住宅小区]
#                                ...
# 62927    [121.430997, 31.201467, 新华路一号(东北门), 通行设施;临街院门;...
# 63462       [121.410568, 31.192226, 虹桥城市花园, 商务住宅;住宅区;住宅小区]
# 64461     [121.488222, 31.117025, 鹏欣一品漫城4期, 商务住宅;住宅区;住宅小区]
# 64673    [121.285396, 31.199214, 西郊庄园物业接待处, 生活服务;生活服务场所...
# 65970          [121.378297, 31.172861, 陶然居, 商务住宅;住宅区;住宅小区]
# 67482      [121.485414, 31.106661, 翡翠别墅(浦锦路), 商务住宅;住宅区;别墅]
# 68878         [121.388037, 31.180607, 豪嘉府邸, 商务住宅;住宅区;住宅小区]
# 70729       [121.390648, 31.180593, 虹梅别墅71号, 商务住宅;住宅区;住宅区]
# 72438        [121.510681, 31.080172, 绿地峰尚汇, 商务住宅;住宅区;住宅小区]
# 72787        [121.392312, 31.145824, 万源城御溪, 商务住宅;住宅区;住宅小区]
# 77391            [121.29822, 31.161769, 丽都别墅, 商务住宅;住宅区;别墅]
# 77749    [121.291567, 31.168771, 第1别墅(高泾店), 生活服务;中介机构;中...
# 78467        [120.917766, 31.036873, 金溪路, 地名地址信息;交通地名;道路名]
# 79083          [121.438281, 31.224018, 嘉天汇, 商务住宅;住宅区;住宅小区]
# 79169    [121.457665, 31.228834, 南京西路与南汇路交叉口, 地名地址信息;交通...
# 79638       [121.459346, 31.229006, 经典茂名公寓, 商务住宅;住宅区;住宅小区]
# 79642       [121.432257, 31.230404, 静鼎安邦府邸, 商务住宅;住宅区;住宅小区]
# 79788         [121.445911, 31.218479, 御华山, 商务住宅;楼宇;商住两用楼宇]
# 79895          [121.45696, 31.230589, 御品大厦, 商务住宅;住宅区;住宅小区]
# 80273          [121.439335, 31.221253, 愚园坊, 商务住宅;住宅区;住宅小区]
# 80329    [121.473336, 31.220495, 锦麟天地雅苑停车场, 交通设施服务;停车场;...
# 80401        [121.466350, 31.215912, 香山路, 地名地址信息;交通地名;道路名]
# 80413    [121.473376, 31.218986, 华府天地停车场, 交通设施服务;停车场;公共...
# 80521       [121.470442, 31.221451, 淮海中路, 地名地址信息;交通地名;道路名]
# 80574    [121.491193, 31.203018, 中山南路1814弄小区, 商务住宅;住宅区;...
# 80638       [121.497989, 31.21231, 黄浦区人才公寓, 商务住宅;住宅区;住宅小区]
# 80690       [121.503662, 31.218244, 绿城·黄浦湾, 商务住宅;住宅区;住宅小区]
# 80886      [121.461331, 31.222288, 凯德·茂名公馆, 商务住宅;住宅区;住宅小区]
# 80909          [121.485057, 31.20872, 黄浦丽园, 商务住宅;住宅区;住宅小区]
# 81827     [121.462836, 31.209445, 绍兴路76弄11号, 商务住宅;住宅区;住宅区]
# Length: 115, dtype: object
