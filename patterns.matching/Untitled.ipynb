# %%
import pandas as pd
import tushare as ts

# %%
ts.get_index()
# Out:
#       code    name  change        open    preclose       close        high  \
# 0   000001    上证指数   -0.21   3470.5089   3488.0090   3480.8334   3495.4533
# 1   000002    Ａ股指数   -0.20   3634.8942   3653.2691   3645.8022   3661.1110
# 2   000003    Ｂ股指数   -0.68    346.9314    347.1196    344.7466    346.9314
# 3   000008    综合指数    0.90   3315.2564   3327.8936   3357.7907   3359.3613
# 4   000009   上证380   -1.39   5592.2970   5612.0558   5533.9089   5592.2970
# 5   000010   上证180    0.68   9161.5815   9207.1519   9269.7531   9287.4769
# 6   000011    基金指数    0.12   6379.9125   6391.9458   6399.3431   6411.8584
# 7   000012    国债指数    0.00    161.2814    161.2659    161.2732    161.2842
# 8   000016    上证50    1.22   3063.2335   3079.1178   3116.8331   3118.7622
# 9   000017     新综指   -0.20   2930.8387   2945.6534   2939.6343   2951.9922
# 10  000300   沪深300    0.47   4234.1101   4256.1021   4275.8986   4287.8576
# 11  000905   中证500   -1.97   6277.7418   6313.4420   6189.3413   6277.7418
# 12  399001    深证成指   -1.06  11210.0640  11278.7810  11159.6760  11244.1810
# 13  399002    深成指R   -1.06  13391.7610  13473.8520  13331.5660  13432.5170
# 14  399003    成份Ｂ指   -0.09   6703.2780   6713.6820   6707.3250   6732.7930
# 15  399004  深证100R   -0.18   5893.8320   5925.4130   5914.9060   5950.7340
# 16  399005    中小板指   -1.36   7473.0490   7522.6910   7420.6570   7497.6280
# 17  399006    创业板指   -2.66   1766.7670   1782.3990   1735.0570   1767.7770
# 18  399008   中小300   -1.62   1468.9360   1478.3020   1454.3140   1470.7460
# 19  399100   新 指 数   -1.44   8618.6880   8672.0760   8546.9120   8625.9620
# 20  399101    中小板综   -1.72  11212.0130  11282.5100  11088.6110  11214.8250
# 21  399106    深证综指   -1.66   1898.4420   1909.5710   1877.8180   1898.6550
# 22  399107    深证Ａ指   -1.67   1985.2870   1996.9420   1963.6420   1985.5100
# 23  399108    深证Ｂ指   -0.24   1196.3630   1200.1330   1197.2980   1200.4350
# 24  399333    中小板R   -1.36   8231.4640   8286.1450   8173.7550   8258.5370
# 25  399606    创业板R   -2.66   1840.2840   1856.5670   1807.2550   1841.3360
#
#            low       volume     amount
# 0    3454.7259    207253403  2426.5796
# 1    3618.4057    206876436  2424.1341
# 2     343.9168       376966     2.4455
# 3    3310.2489     56644124   651.2915
# 4    5516.9292     44055128   525.2076
# 5    9157.7526     97959036  1220.0475
# 6    6376.5005     40646874   252.9762
# 7     161.2449       172772     1.6657
# 8    3062.5284     55607397   729.9026
# 9    2917.5400    206715405  2417.2355
# 10   4232.7727    145210164  1944.0180
# 11   6170.1606     80733495   881.0621
# 12  11119.3160  19479497333  2514.1220
# 13  13283.3530  10715753561  1441.2727
# 14   6677.5400     10606394     0.8195
# 15   5878.4850   4471339673   699.9662
# 16   7395.3430   2257868810   366.7250
# 17   1732.9800   2011389247   303.6853
# 18   1449.6740   4524120459   599.9066
# 19   8518.8730  19230426318  2497.4267
# 20  11055.8360   7555467445  1003.7447
# 21   1872.1240  19479497333  2514.1220
# 22   1957.6860  19444506918  2512.2625
# 23   1192.5500     34990415     1.8595
# 24   8145.8720   2257868810   366.7250
# 25   1805.0920   2011389247   303.6853

# %%
ts.get_apis()
# Out:
# (<pytdx.hq.TdxHq_API at 0x7fa34a7c6400>,
#  <pytdx.exhq.TdxExHq_API at 0x7fa34a7be7f0>)

# %%
ts.get_fund_info(502049)
# Out:
#                      jjqc          jjjc                 clrq ssrq xcr ssdd  \
# symbol
# 502049  易方达上证50指数分级证券投资基金  易方达上证50指数分级A  2015-04-15 00:00:00   --  --   --
#
#        Type1Name Type2Name Type3Name  jjgm   jjfe jjltfe               jjferq  \
# symbol
# 502049       开放式     分级-固收  分级-一般股票型  0.61  0.613  0.613  2018-01-16 00:00:00
#
#         quarter          glr         tgr
# symbol
# 502049        1  易方达基金管理有限公司  交通银行股份有限公司

# %%
a=ts.get_sz50s()
# Out:
# Install xlrd >= 0.9.0 for Excel support
# /usr/local/lib/python3.4/dist-packages/tushare/stock/classifying.py:223: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   ct.PAGES['sz50b']), parse_cols=[0,1])

# %%
a

# %%
temp=ts.get_k_data('000016',index=True,start='2006-01-01', end='2017-12-31',autype='qfq')

# %%
# ?ts.get_k_data

# %%
import numpy as np

from bokeh.plotting import figure, output_file, show

# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)
output_file("color_scatter.html", title="color_scatter.py example", mode="cdn")

TOOLS="crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)

# %%
p
# Out:
# Figure(id='13c34ac2-6577-43cc-aaf3-d9d98e2e3261', ...)

# %%
show (p)
